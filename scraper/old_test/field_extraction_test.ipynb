# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd 
from sentence_transformers import SentenceTransformer, util
from deep_translator import GoogleTranslator
import re
from field import field_extraction

df = pd.read_csv("/Users/alessandromolinarroet/Desktop/web_application/arbeitnow_jobs.csv")
field_extraction(df, treshold=0.6, model_name="sentence-transformers/paraphrase-multilingual-mpnet-base-v2")
# Out:
#                             company_name                            tags  \
# 0     LABLIONS software & solutions GmbH                    ['Helpdesk']
# 1                             Nexun GmbH   ['Management', 'Team Leader']
# 2                          K-tronik GmbH                 ['Engineering']
# 3                         Rahantech GmbH        ['Software Development']
# 4             Walther Systemtechnik GmbH         ['Strategic Marketing']
# ...                                  ...                             ...
# 1178                   Melo Holding GmbH                          ['IT']
# 1179              Franco Consulting GmbH  ['Remote', 'Online Marketing']
# 1180                      Rahantech GmbH             ['Web Development']
# 1181  Consilium Vermögensmanagement GmbH                     ['Finance']
# 1182     Schattenspringer Abenteuerparks   ['Management', 'Team Leader']
#
#       created_at                                        job_types  \
# ...

# %%
print(df["field"].value_counts())
print(df["level"].value_counts())
# Out:
# field
# Other                                           266
# Marketing and Communications                     93
# IT Support and Network Administration            85
# Finance and Accounting                           73
# Software Engineering                             71
# Sales and Account Management                     70
# Consulting and Strategy                          41
# Human Resources and Talent Acquisition           40
# Electrical and Electronics Engineering           38
# Manufacturing and Industrial Engineering         28
# Full Stack Developer                             27
# Product Management                               25
# Project and Program Management                   25
# Social Media Manager                             22
# Customer Success and Support                     22
# Construction and Skilled Trades                  21
# Management                                       18
# Information Technology                           18
# ...

# %%
print(df[df["field"]=="Other"]["title"])
# Out:
# 0           Werkstudent (all genders) First-Level-Support
# 2                         Atlassian Administrator (m/w/x)
# 31               Masseur:in (m/w/d) gesucht in Estenfeld!
# 35      Automation-Developer (n8n / Zapier / Make / Po...
# 38      n8n Developer / Automation Developer (m/w/d) 1...
#                               ...
# 1157                      Baukoordinator (m/w/d) -Tiefbau
# 1168                      Baukoordinator (m/w/d) -Tiefbau
# 1171                      Baukoordinator (m/w/d) -Tiefbau
# 1174                      Baukoordinator (m/w/d) -Tiefbau
# 1182                    Kapitän*in im Kletterpark (m/w/d)
# Name: title, Length: 266, dtype: object
