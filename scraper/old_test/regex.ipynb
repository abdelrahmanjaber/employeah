# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from skill_extraction import extract_skill


# Load dataset
df = pd.read_csv("/Users/alessandromolinarroet/Desktop/web_application/arbeitnow_jobs.csv")
skill_path = "skills.txt"

extract_skill(df,skill_path=skill_path)
# Out:
#                             company_name                            tags  \
# 0     LABLIONS software & solutions GmbH                    ['Helpdesk']
# 1                             Nexun GmbH   ['Management', 'Team Leader']
# 2                          K-tronik GmbH                 ['Engineering']
# 3                         Rahantech GmbH        ['Software Development']
# 4             Walther Systemtechnik GmbH         ['Strategic Marketing']
# ...                                  ...                             ...
# 1178                   Melo Holding GmbH                          ['IT']
# 1179              Franco Consulting GmbH  ['Remote', 'Online Marketing']
# 1180                      Rahantech GmbH             ['Web Development']
# 1181  Consilium Vermögensmanagement GmbH                     ['Finance']
# 1182     Schattenspringer Abenteuerparks   ['Management', 'Team Leader']
#
#       created_at                                        job_types  \
# 0     1764325922  ['Working student', 'hilfstätigkeit / student']
# 1     1764325922                               ['berufserfahren']
# 2     1764325921                               ['berufserfahren']
# 3     1764324109                                        ['entry']
# 4     1764324109                                               []
# ...          ...                                              ...
# 1178  1763726543                                               []
# 1179  1763726543                               ['berufserfahren']
# 1180  1763726542                   ['professional / experienced']
# 1181  1763726541                                               []
# 1182  1763726540                      ['Contract', 'teamleitung']
#
#          location                                        description  \
# 0       Karlsruhe  <p>Die LABLIONS software &#x26; solutions GmbH...
# 1         Leipzig  <p>Nexun ist eine schnell wachsende Plattform ...
# 2          Munich  <h2>Projektbeschreibung:</h2>\n<p>Technologie ...
# 3          Munich  <h2>Tasks</h2>\n<ul>\n<li>Develop and maintain...
# 4     Germersheim  <p>Willkommen bei <strong>Walther Systemtechni...
# ...           ...                                                ...
# 1178       Munich  <p>Die MELO Holding übernimmt die strategische...
# 1179       Burgau  <p>Du hast bereits erfolgreich 5- bis 6-stelli...
# 1180    Frankfurt  <h2>Tasks</h2>\n<ul>\n<li>Design and build mob...
# 1181     Dortmund  <p>Wir sind die <strong>Consilium Vermögensman...
# 1182      Hamburg  <p><strong>Leite unseren Kletterpark mit Überb...
#
#                                                    slug  remote  \
# 0     werkstudent-all-genders-first-level-support-ka...   False
# 1     projektentwickler-erneuerbare-energien-leipzig...   False
# 2                  atlassian-administrator-munich-49285   False
# 3                       software-developer-munich-74461   False
# 4               ki-marketing-manager-germersheim-368900   False
# ...                                                 ...     ...
# 1178               it-systemadministrator-munich-277058   False
# 1179  erfahrener-performance-marketing-manager-in-te...    True
# 1180                 frontend-developer-frankfurt-25462   False
# 1181  kaufmannischen-sachbearbeiter-versicherungen-f...   False
# 1182            kapitanin-im-kletterpark-hamburg-202057   False
#
#                                                   title  \
# 0         Werkstudent (all genders) First-Level-Support
# 1        Projektentwickler Erneuerbare Energien (m/w/d)
# 2                       Atlassian Administrator (m/w/x)
# 3                                    Software Developer
# 4                          KI Marketing Manager (m/w/d)
# ...                                                 ...
# 1178                     IT Systemadministrator (m/w/d)
# 1179  Erfahrener Performance Marketing Manager in Te...
# 1180                         Frontend Developer (m/f/d)
# 1181  Kaufmännischen Sachbearbeiter Versicherungen &...
# 1182                  Kapitän*in im Kletterpark (m/w/d)
#
#                                                     url  \
# 0     https://www.arbeitnow.com/jobs/companies/labli...
# 1     https://www.arbeitnow.com/jobs/companies/nexun...
# 2     https://www.arbeitnow.com/jobs/companies/k-tro...
# 3     https://www.arbeitnow.com/jobs/companies/rahan...
# 4     https://www.arbeitnow.com/jobs/companies/walth...
# ...                                                 ...
# 1178  https://www.arbeitnow.com/jobs/companies/melo-...
# 1179  https://www.arbeitnow.com/jobs/companies/franc...
# 1180  https://www.arbeitnow.com/jobs/companies/rahan...
# 1181  https://www.arbeitnow.com/jobs/companies/consi...
# 1182  https://www.arbeitnow.com/jobs/companies/schat...
#
#                                                  skills
# 0                                   [Javascript, Linux]
# 1                                                    []
# 2                           [Java, Jira, Python, Scrum]
# 3     [Agile, Aws, Azure, C, Ci/Cd, Git, Java, Javas...
# 4                                                    []
# ...                                                 ...
# 1178                          [Bash, Linux, Powershell]
# 1179                                                 []
# 1180  [Css, Git, Html, Javascript, React, Vue, Webpack]
# 1181                                                 []
# 1182                                                 []
#
# [1183 rows x 11 columns]

# %%
import ast

def to_list(x):
    if isinstance(x, list):
        return x
    if x is None or x != x: 
        return []
    if isinstance(x, str):
        try:
            return ast.literal_eval(x)
        except:
            return [i.strip() for i in x.strip("[]").split(",")]
    return [x]

df["tags"] = df["tags"].apply(to_list)


skill_cols = [f"skill{i}" for i in range(1, 21)]
tag_dict = {}

for _, row in df.iterrows():
    tags = row["tags"]

    skills = [row[col] for col in skill_cols if col in df.columns and row[col] and str(row[col]).strip()]

    for t in tags:
        if t not in tag_dict:
            tag_dict[t] = {}  
        for skill in skills:
            if skill in tag_dict[t]:
                tag_dict[t][skill] += 1
            else:
                tag_dict[t][skill] = 1

# %%
for tag in tag_dict:
    print(tag)
    print(tag_dict[tag])
# Out:
# Helpdesk
# {'Javascript': 1, 'Linux': 3, 'Vmware': 1}
# Management
# {'R': 4, 'Agile': 1, 'Aws': 1, 'Azure': 1, 'Jira': 1, 'Linux': 1, 'Scrum': 1, 'Sso': 1, 'Go': 1}
# Team Leader
# {'R': 4, 'Agile': 1, 'Aws': 1, 'Azure': 1, 'Jira': 1, 'Linux': 1, 'Scrum': 1, 'Sso': 1, 'Go': 1}
# Engineering
# {'Java': 1, 'Jira': 2, 'Python': 13, 'Scrum': 4, 'Ci/Cd': 7, 'Flask': 2, 'Go': 3, 'Graphql': 1, 'Javascript': 5, 'Next.Js': 3, 'Node.Js': 2, 'React': 5, 'Typescript': 4, 'Matlab': 2, 'Azure': 4, 'C': 7, 'Powershell': 2, 'Linux': 8, 'Sql': 5, 'Agile': 3, 'Css': 1, 'Git': 2, 'Html': 1, 'Cybersecurity': 1, 'Ansible': 1, 'Aws': 2, 'Cloud Computing': 1, 'Docker': 2, 'Gcp': 2, 'Gitlab': 4, 'Iac': 3, 'Jenkins': 1, 'Kubernetes': 4, 'Lambda': 1, 'Puppet': 1, 'Terraform': 4, 'R': 9, 'Mysql': 2, 'Php': 1, 'Vmware': 1, 'Grafana': 3, 'Mongodb': 1, 'Postgresql': 3, 'Prometheus': 3, 'Rust': 1, 'Vue': 1, 'Argo Cd': 1, 'Github Actions': 3, 'Helm': 1, 'Data Pipelines': 1, 'Selenium': 1, 'Sqlalchemy': 1, 'Algorithms': 1, 'Computer Vision': 1, 'Deep Learning': 1, 'Pytorch': 1, 'Tensorflow': 1, 'Data Modeling': 1, 'Microservices': 1, 'Nestjs': 1, 'Pulumi': 1, 'Kind': 2, 'Zapier': 2}
# Software Development
# {'Agile': 6, 'Aws': 12, 'Azure': 14, 'C': 11, 'Ci/Cd': 16, 'Git': 11, 'Java': 14, 'Javascript': 21, 'Mongodb': 3, 'Mysql': 5, 'Php': 7, 'Postgresql': 13, 'Python': 17, 'Scrum': 14, 'Sql': 22, 'Blockchain': 3, 'Docker': 8, 'Dynamodb': 1, 'Graphql': 9, 'Json': 5, 'Microservices': 4, 'Rust': 2, 'Node.Js': 12, 'Typescript': 31, 'Data Modeling': 1, 'Data Pipelines': 4, 'Looker': 1, 'Css': 11, 'Gcp': 9, 'React': 18, 'Redis': 3, 'Tailwind': 3, 'Api Design': 2, 'Langchain': 11, 'Next.Js': 4, 'Openai Api': 1, 'Supabase': 2, 'Html': 5, 'Vue': 5, 'Kubernetes': 5, 'Bootstrap': 1, 'Go': 8, 'Nlp': 2, 'Cloudflare': 1, 'Sentry': 1, 'Etl': 2, 'Machine Learning': 7, 'Swift': 1, 'Gitlab': 5, 'Jenkins': 4, 'Selenium': 1, 'Pytorch': 3, 'R': 4, 'Tensorflow': 5, 'Serverless': 1, 'Elixir': 1, 'Webassembly': 1, 'Big Data': 1, 'Django': 1, 'Julia': 3, 'Flutter': 1, 'Android': 2, 'Argo Cd': 1, 'Helm': 1, 'Jira': 1, 'Kotlin': 1, 'Numpy': 1, 'Pandas': 1, 'Redux': 1, 'Sass': 1, 'Figma': 1, 'Sso': 1, 'Laravel': 2, 'Linux': 1, 'Reinforcement Learning': 1, 'Information Security': 1, 'Shell Scripting': 1, 'Cobol': 1, 'Nestjs': 3, 'Nosql': 1, 'Jquery': 1, 'Unity': 1, 'Zapier': 1, 'Bash': 1, 'Rabbitmq': 2, 'Shell': 1, 'Kind': 1, 'Data Engineering': 1, 'Lambda': 1, 'Vault': 1, 'Openshift': 1, 'Github Actions': 1, 'Terraform': 1, 'Artificial Intelligence': 1, 'Firebase': 1}
# Strategic Marketing
# {'Ci/Cd': 1, 'Go': 1, 'R': 1, 'Segment': 2}
# Business Development
# {'Go': 6, 'Blockchain': 1, 'Nlp': 1, 'Typescript': 1, 'Azure': 1, 'Agile': 1, 'Zapier': 1, 'Jira': 1, 'R': 1}
# Asset
# {}
# Fonds Management
# {}
# IT
# {'Agile': 6, 'Microservices': 2, 'Scrum': 12, 'Zapier': 3, 'Data Engineering': 2, 'Data Modeling': 1, 'Dbt': 1, 'Python': 8, 'Sql': 8, 'Tableau': 2, 'Go': 3, 'C': 12, 'Mysql': 2, 'Php': 3, 'Django': 1, 'Gitlab': 2, 'Java': 4, 'Selenium': 1, 'Powershell': 4, 'Ci/Cd': 3, 'Git': 4, 'Helm': 1, 'Iac': 2, 'Istio': 1, 'Kubernetes': 3, 'Prometheus': 2, 'Pulumi': 1, 'Rabbitmq': 1, 'Terraform': 4, 'Zabbix': 1, 'Next.Js': 1, 'React': 2, 'Android': 1, 'Artificial Intelligence': 1, 'Segment': 1, 'Ansible': 3, 'Linux': 10, 'Sso': 1, 'Cybersecurity': 2, 'Looker': 4, 'Javascript': 2, 'Nestjs': 1, 'Postgresql': 2, 'Aws': 4, 'Azure': 8, 'Html': 2, 'Typescript': 1, 'Jira': 2, 'Snowflake': 1, 'Databricks': 1, 'Docker': 3, 'Vault': 1, 'Css': 2, 'Json': 1, 'Vue': 1, 'Blockchain': 1, 'Cobol': 1, 'Jenkins': 2, 'Openshift': 1, 'Shell': 2, 'R': 1, 'Kind': 3, 'C++': 1, 'Bash': 2}
# Marketing and Communication
# {'Go': 6, 'Illustrator': 3, 'Photoshop': 5, 'Wordpress': 10, 'Figma': 2, 'Css': 2, 'Html': 2, 'Javascript': 1, 'Php': 1, 'Cybersecurity': 1, 'R': 4, 'C': 2, 'Segment': 2}
# Remote
# {'Ansible': 3, 'Azure': 6, 'Ci/Cd': 11, 'Linux': 3, 'Powershell': 3, 'Terraform': 4, 'R': 5, 'Blockchain': 2, 'Docker': 6, 'Dynamodb': 1, 'Git': 4, 'Graphql': 3, 'Json': 4, 'Microservices': 1, 'Postgresql': 5, 'Rust': 3, 'Node.Js': 5, 'Typescript': 10, 'Zapier': 2, 'Airflow': 1, 'Python': 11, 'Sql': 5, 'Tableau': 3, 'C': 9, 'Flask': 1, 'Go': 15, 'Javascript': 5, 'Next.Js': 2, 'React': 8, 'Agile': 6, 'Data Engineering': 1, 'Data Modeling': 1, 'Dbt': 1, 'Illustrator': 3, 'Scrum': 6, 'Aws': 10, 'Information Security': 5, 'Java': 9, 'Kubernetes': 9, 'Css': 3, 'Html': 3, 'Gitlab': 2, 'Jenkins': 2, 'Selenium': 1, 'Wordpress': 4, 'Machine Learning': 1, 'Serverless': 1, 'Vue': 4, 'Figma': 5, 'Looker': 2, 'Julia': 3, 'Mysql': 1, 'Php': 2, 'Rest Api': 1, 'Grafana': 2, 'Iac': 2, 'Mongodb': 2, 'Openshift': 3, 'Prometheus': 2, 'Powerbi': 1, 'Cobol': 2, 'Langchain': 2, 'Nestjs': 1, 'Nosql': 1, 'Android': 1, 'Unity': 1, 'Cybersecurity': 1, 'Shell': 1, 'Photoshop': 2, 'Kind': 1, 'Unreal Engine': 1}
# Business Consulting
# {'Ansible': 1, 'Azure': 3, 'Ci/Cd': 1, 'Linux': 2, 'Powershell': 1, 'Terraform': 1, 'Vmware': 1, 'R': 2, 'Go': 4, 'Scrum': 1, 'C': 2, 'Docker': 1, 'Javascript': 2, 'Mysql': 1, 'Node.Js': 1, 'Agile': 1, 'Jira': 2, 'Groovy': 1, 'Python': 1, 'Sql': 1}
# Business Operations
# {'Information Security': 1}
# System and Network Administration
# {'Powershell': 3, 'Azure': 5, 'Machine Learning': 2, 'Sql': 3, 'Vmware': 4, 'Docker': 4, 'Linux': 60, 'Ansible': 1, 'Bash': 1, 'Gitlab': 1, 'Jira': 1, 'Kubernetes': 2, 'Data Engineering': 1, 'Typescript': 1, 'Aws': 3, 'Kind': 1, 'Gcp': 2, 'Java': 2, 'Javascript': 2, 'Nosql': 2}
# Social Media Manager
# {'Segment': 2, 'Figma': 1, 'R': 1}
# Finance
# {'R': 5, 'Crystal': 1, 'Julia': 6, 'C': 2, 'Looker': 1, 'Powerbi': 1, 'Tableau': 1}
# Controlling
# {'R': 2}
# Power Engineering and Environmental Engineering
# {}
# Process Management
# {'R': 1, 'Scrum': 1}
# HR
# {'Blockchain': 1, 'R': 1}
# Project Management
# {'R': 7, 'Julia': 1, 'Javascript': 1, 'Python': 1, 'Go': 1, 'Scrum': 2, 'Jira': 2}
# Beauty
# {}
# Wellness
# {}
# Applications Administration
# {'Azure': 2, 'Vmware': 2, 'Aws': 1}
# Information technology
# {'Javascript': 9, 'Python': 11, 'Zapier': 9, 'Artificial Intelligence': 1, 'Azure': 2, 'Ci/Cd': 4, 'Databricks': 1, 'Iac': 1, 'Terraform': 1, 'Jira': 1, 'Css': 1, 'Git': 3, 'Html': 1, 'React': 1, 'Vue': 1, 'Aws': 1, 'Docker': 1, 'Gcp': 1, 'Gitlab': 1, 'Go': 1, 'Microservices': 1, 'Postgresql': 1, 'Scrum': 1, 'Bash': 1, 'C': 1, 'Linux': 1}
# professional
# {'Javascript': 10, 'Python': 9, 'Zapier': 9, 'Agile': 2, 'Aws': 1, 'Data Pipelines': 1, 'Etl': 1, 'Go': 1, 'Graphql': 1, 'Json': 1, 'Microservices': 1, 'Scrum': 1, 'Serverless': 1, 'Typescript': 1}
# Customer Service
# {'C': 1, 'R': 2}
# Recruitment and Selection
# {'R': 1}
# Building
# {'Go': 2}
# Supply
# {'Go': 2}
# Safety Services Engineering
# {'Go': 2}
# Private Banking
# {}
# Purchasing
# {'R': 1}
# Materials Administration and Logistics
# {'R': 1}
# Accounts Receivable
# {'Julia': 1}
# Information Systems
# {'Jira': 1, 'Azure': 1, 'Scrum': 1}
# Compliance
# {}
# Security
# {}
# Marketing Manager
# {'Go': 6, 'C': 1, 'Wordpress': 4, 'Figma': 4, 'R': 3, 'Illustrator': 1, 'Photoshop': 1}
# Product Management
# {'Api Design': 1, 'Ci/Cd': 5, 'Aws': 1, 'Azure': 1, 'Gcp': 1, 'Python': 3, 'Sql': 2, 'Go': 2, 'Java': 1, 'Kotlin': 1, 'Node.Js': 2, 'Dbt': 1, 'Looker': 1, 'Agile': 2, 'Microservices': 1, 'React': 1, 'Typescript': 1, 'R': 3, 'Segment': 1, 'Vmware': 1, 'Figma': 1, 'Gitlab': 1, 'Kind': 1, 'Machine Learning': 1, 'Postgresql': 1}
# Data Processing
# {'Data Pipelines': 1, 'Graphql': 1, 'Sso': 1}
# Data Engineer
# {'Data Pipelines': 1, 'Graphql': 1, 'Sso': 1}
# Directors
# {'Go': 24, 'R': 4}
# Chief Executives
# {'Go': 24, 'R': 4}
# Graphic Arts and Communication Design
# {'Illustrator': 6, 'Photoshop': 6, 'C': 1, 'Css': 1, 'Html': 1, 'Figma': 3, 'Agile': 1, 'R': 2}
# Online Marketing
# {'Figma': 2, 'Wordpress': 3, 'C': 1, 'Photoshop': 2, 'Snowflake': 1, 'Sql': 1, 'Go': 1, 'Dart': 1}
# bachelor's degree
# {'Artificial Intelligence': 1, 'Azure': 1, 'Ci/Cd': 2, 'Databricks': 1, 'Iac': 1, 'Terraform': 1, 'Algorithms': 2, 'C': 1, 'Computer Graphics': 1, 'Agile': 2, 'Css': 1, 'Git': 1, 'Html': 1, 'Javascript': 1, 'React': 1, 'Typescript': 1, 'Jira': 1, 'Python': 1, 'Computer Vision': 1, 'Deep Learning': 1, 'Pytorch': 1, 'Tensorflow': 1}
# Distribution Marketing
# {'R': 3, 'Wordpress': 1}
# Web Development
# {'Figma': 1, 'React': 4, 'Css': 4, 'Html': 4, 'Wordpress': 4, 'Docker': 2, 'Git': 4, 'Microservices': 1, 'Python': 1, 'Vue': 3, 'Ci/Cd': 1, 'Json': 1, 'Mysql': 1, 'Php': 2, 'Rest Api': 1, 'Typescript': 1, 'Javascript': 3, 'Webpack': 1}
# IT Security
# {'Information Security': 1, 'Ansible': 3, 'Aws': 1, 'Azure': 1, 'C': 1, 'Docker': 1, 'Go': 1, 'Grafana': 1, 'Iac': 1, 'Kubernetes': 2, 'Mongodb': 1, 'Openshift': 1, 'Postgresql': 1, 'Prometheus': 1, 'Python': 2, 'R': 1, 'React': 1, 'Rust': 1, 'Terraform': 1, 'Typescript': 1, 'Vue': 1, 'Cybersecurity': 2, 'Linux': 2, 'Machine Learning': 1, 'Ci/Cd': 1, 'Gitlab': 1}
# Quality Management
# {'C': 1}
# Auditor
# {}
# Administration
# {'Gcp': 1, 'Ansible': 1, 'Docker': 1, 'Kind': 1, 'Kubernetes': 1, 'Linux': 1, 'Nginx': 1, 'Puppet': 1}
# Mergers & Acquisitions
# {}
# Consulting
# {'Azure': 3, 'C': 4, 'Powershell': 2, 'Scrum': 1, 'Python': 3, 'Sql': 4, 'Go': 2, 'Linux': 6, 'Mysql': 1, 'Php': 1, 'Vmware': 1, 'Aws': 1, 'Docker': 1, 'Grafana': 3, 'Iac': 2, 'Kubernetes': 3, 'Mongodb': 1, 'Postgresql': 1, 'Prometheus': 3, 'R': 1, 'React': 1, 'Rust': 1, 'Terraform': 2, 'Typescript': 1, 'Vue': 1, 'Agile': 1, 'Argo Cd': 1, 'Ci/Cd': 2, 'Github Actions': 2, 'Gitlab': 2, 'Helm': 1, 'Kind': 2}
# Data Scientist
# {'Bash': 1, 'Machine Learning': 1, 'Python': 1, 'R': 1}
# CRM
# {}
# Direct Marketing
# {}
# Training
# {'Agile': 4, 'Looker': 1, 'Scrum': 4}
# Development
# {'Agile': 4, 'Looker': 1, 'Scrum': 4}
# Media
# {'Css': 1, 'Html': 1, 'Illustrator': 2, 'Photoshop': 2, 'Wordpress': 1, 'Agile': 4, 'Scrum': 3, 'Figma': 1, 'C': 1, 'Unreal Engine': 1}
# Screen and Web Design
# {'Css': 1, 'Html': 1, 'Illustrator': 2, 'Photoshop': 2, 'Wordpress': 1, 'Agile': 4, 'Scrum': 3, 'Figma': 1, 'C': 1, 'Unreal Engine': 1}
# SAP/ERP Consulting
# {}
# Process Engineering
# {}
# Media Planning
# {}
# Internet and software
# {'Algorithms': 1, 'C': 1, 'Computer Graphics': 1, 'Agile': 1, 'Aws': 1, 'Data Pipelines': 1, 'Etl': 1, 'Go': 1, 'Graphql': 1, 'Javascript': 1, 'Json': 1, 'Microservices': 1, 'Scrum': 1, 'Serverless': 1, 'Typescript': 1}
# Automation Engineering
# {}
# Personnel Specialist
# {}
# Marketing and pr
# {'R': 1, 'Agile': 1}
# high school or equivalent
# {'R': 1}
# vocational
# {'Css': 1, 'Git': 1, 'Html': 1, 'React': 1, 'Vue': 1}
# Public Relations
# {'R': 1, 'C': 2}
# Corporate Communication
# {'R': 1, 'C': 2}
# Quality Assurance
# {'Agile': 1, 'R': 2, 'Git': 1, 'Javascript': 1, 'Jira': 1, 'Php': 1, 'Typescript': 1}
# Inspection
# {'Agile': 1, 'R': 2, 'Git': 1, 'Javascript': 1, 'Jira': 1, 'Php': 1, 'Typescript': 1}
# Marketing Assistant
# {}
# Other
# {'R': 1}
# associate's degree
# {'R': 1}
# high school coursework
# {'Aws': 1, 'Azure': 1, 'Ci/Cd': 2, 'Docker': 1, 'Gcp': 1, 'Git': 2, 'Gitlab': 1, 'Go': 1, 'Microservices': 1, 'Postgresql': 1, 'Scrum': 1, 'Bash': 1, 'C': 1, 'Linux': 1, 'Python': 1}
# Market Research
# {}
# Analysis
# {}
# Business Analyst
# {}
# Automotive Engineering
# {'R': 2}
# Database Administration
# {'Linux': 1, 'Shell': 1, 'Sql': 1}
# Sales Engineer
# {}
# Embedded Systems
# {'C': 1, 'Embedded Systems': 1, 'Java': 1, 'Linux': 1, 'R': 1}
# Firmware Development
# {'C': 1, 'Embedded Systems': 1, 'Java': 1, 'Linux': 1, 'R': 1}

# %%
import re
import pandas as pd
import requests
import time

MAX_SKILLS = 20

# skills list
known_skills = set(
    line.strip().lower()
    for line in open("skills.txt", "r", encoding="utf-8").readlines()
    if line.strip()
)

# regex building
sorted_skills = sorted(known_skills, key=len, reverse=True)
regex = r"\b(?:" + "|".join(re.escape(s) for s in sorted_skills) + r")\b"
pattern = re.compile(regex, re.IGNORECASE)

# Load dataset
df = pd.read_csv("/Users/alessandromolinarroet/Desktop/web_application/Scapers/arbeitnow_jobs.csv")

# Prepare skill columns
skill_columns = [f"skill{i}" for i in range(1, MAX_SKILLS + 1)]
for col in skill_columns:
    df[col] = ""


for idx, description in enumerate(df["description"]):
    # Regular regex extraction
    matches = pattern.findall(str(description))
    extracted = sorted({m.title() for m in matches})[:MAX_SKILLS]
    
    # save skills
    for i, skill in enumerate(extracted):
        df.at[idx, f"skill{i+1}"] = skill
    
    # Every 1000 jobs, call LLM to discover new skills
    if (idx + 1) % 1000 == 0 or idx == len(df) - 1:
        print(f"\nProcessed {idx + 1} jobs. Calling LLM to discover new skills...")
        
        prompt = f"""
        Analyze these job descriptions and list ANY technical skills, tools, frameworks, or technologies mentioned that are NOT in this list:
        {', '.join(sorted(known_skills))}. Job descriptions sample (first 5): {description}
        Return ONLY a comma-separated list of new skills found (lowercase). If none found, return "none".
        """

        # Call Hugging Face Inference API (free tier: generous limits)
        API_URL = "https://api-inference.huggingface.co/models/mistralai/Mixtral-8x7B-Instruct-v0.1"
        
        payload = {
            "inputs": prompt,
            "parameters": {
                "max_new_tokens": 200,
                "temperature": 0.3
            }
        }
        
        try:

            response = requests.post(API_URL, json=payload)
            response.raise_for_status() # **Crucial: Checks for 4xx or 5xx errors**

            response_data = response.json()

            # Check if the response is a list and has at least one element
            if isinstance(response_data, list) and len(response_data) > 0 and "generated_text" in response_data[0]:
                response_text = response_data[0]["generated_text"]
            else:
                # Handle unexpected response format
                print(f"LLM call failed: Unexpected response format: {response_data}")
                continue # Skip processing this response

            # Extract the answer part (after the prompt)
            answer = response_text.split(prompt)[-1].strip()
            
            # Extract the answer part (after the prompt)
            answer = response_text.split(prompt)[-1].strip()
            print(f"LLM Response: {answer}")
            
            # Parse new skills
            if "none" not in answer.lower():
                new_skills = [s.strip().lower() for s in answer.split(",") if s.strip()]
                new_skills = [s for s in new_skills if s and s not in known_skills]
                
                if new_skills:
                    print(f"Adding {len(new_skills)} new skills: {new_skills}")
                    
                    # Add to known skills
                    known_skills.update(new_skills)
                    
                    # Rebuild regex pattern
                    sorted_skills = sorted(known_skills, key=len, reverse=True)
                    regex = r"\b(?:" + "|".join(re.escape(s) for s in sorted_skills) + r")\b"
                    pattern = re.compile(regex, re.IGNORECASE)
                    
                    # Append to skills.txt
                    with open("skills.txt", "a", encoding="utf-8") as f:
                        for skill in new_skills:
                            f.write(f"\n{skill}")
        
        except requests.exceptions.HTTPError as e:
            # Handle HTTP errors (4xx, 5xx) with the response body
            print(f"LLM call failed (HTTP Error): {e}. Response: {e.response.text}")
        except Exception as e:
            print(f"LLM call failed (General Error): {e}")
        
        # Clear accumulated descriptions
        accumulated_descriptions = []
        time.sleep(1)  # Rate limit courtesy

# Save results
df.to_csv("jobs_with_skills.csv", index=False)
print("\nDone! Results saved.")
# Out:
# Processed 1000 jobs. Calling LLM to discover new skills...
# LLM call failed (HTTP Error): 410 Client Error: Gone for url: https://api-inference.huggingface.co/models/mistralai/Mixtral-8x7B-Instruct-v0.1. Response: {"error":"https://api-inference.huggingface.co is no longer supported. Please use https://router.huggingface.co instead."}
#
# Done! Results saved.
