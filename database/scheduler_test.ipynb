# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
from datetime import datetime
import pandas as pd
import re

from  scheduler import scheduler

# %%
dataset_path = "./data/job_data/ALL_JOBS.csv.gz"
df = pd.read_csv(dataset_path, compression='gzip')
df.head()
# Out:
#                                      Job Title Continent  Country     City  \
# 0  Praktikant:in als Machine Learning Engineer    Europe  Germany  Mülheim
# 1                          IT Internal Auditor    Europe  Germany   Berlin
# 2                        FP&A  Strategy Intern    Europe  Germany   Berlin
# 3                 Mid Market Account Executive    Europe  Germany   Munich
# 4           Account Development Representative    Europe  Germany   Munich
#
#          Date      Company                                        Description  \
# 0  2025-12-05  U-Glow GmbH  <p>Du willst in einem jungen Tech-Team arbeite...
# 1  2025-12-05        SumUp  <p>Are you passionate about making an impact t...
# 2  2025-12-05        SumUp  <p>Over 4 million merchants use our card reade...
# 3  2025-12-05      Samsara  <div class="content-intro"><p><span style="fon...
# 4  2025-12-05      Samsara  <div class="content-intro"><p><span style="fon...
#
# ...

# %%
# Parameters
max_old_date = datetime.now().strftime('%Y-%m-%d')
max_pages = 2

# %%
scheduler(dataset_path=dataset_path, max_old_date=max_old_date, max_pages=max_pages)
# Out:
# ------ STARTING SCRAPING ------
# Arbeitnow scrape until: 2025-12-15
# Page 1
# Page 2
# Arbeitnow collected 108 total jobs
# Adzuna scrape until: 2025-12-15
# 🚩 United States
# WARNING: adzuna scraping failed with status code: 400
# 🚩 United Kingdom
# WARNING: adzuna scraping failed with status code: 400
# 🚩 Germany
# WARNING: adzuna scraping failed with status code: 400
# ✅ Adzuna collected 0 total jobs
# ------ SCRAPING COMPLETE ------
# Extracting skills : 100%|██████████| 108/108 [00:00<00:00, 165.98it/s]
# '(ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')), '(Request ID: 82a1bacc-b379-4518-9c4d-86d37467e6fc)')' thrown while requesting HEAD https://huggingface.co/TechWolf/JobBERT-v2/resolve/main/./modules.json
# Retrying in 1s [Retry 1/5].
# SKILLS EXTRACTED SUCCESFULLY
# Processing job titles: 100%|██████████| 108/108 [00:06<00:00, 15.89it/s]
# FIELDS AND LEVELS EXTRACTED SUCCESSFULLY
#
# ------ MERGING TABLES ------
# ...

# %%
dataset_path = "./data/job_data/ALL_JOBS.csv.gz"
df = pd.read_csv(dataset_path)
df.head()
# Out:
#                                      Job Title Continent  Country     City  \
# 0  Praktikant:in als Machine Learning Engineer    Europe  Germany  Mülheim
# 1                          IT Internal Auditor    Europe  Germany   Berlin
# 2                        FP&A  Strategy Intern    Europe  Germany   Berlin
# 3                 Mid Market Account Executive    Europe  Germany   Munich
# 4           Account Development Representative    Europe  Germany   Munich
#
#          Date      Company                                        Description  \
# 0  2025-12-05  U-Glow GmbH  <p>Du willst in einem jungen Tech-Team arbeite...
# 1  2025-12-05        SumUp  <p>Are you passionate about making an impact t...
# 2  2025-12-05        SumUp  <p>Over 4 million merchants use our card reade...
# 3  2025-12-05      Samsara  <div class="content-intro"><p><span style="fon...
# 4  2025-12-05      Samsara  <div class="content-intro"><p><span style="fon...
#
# ...
