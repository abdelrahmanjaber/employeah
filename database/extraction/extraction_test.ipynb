# %%
# %load_ext autoreload
# %autoreload 2

# %%
import re
import pandas as pd
import ast
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

from extraction import extract_from_description
from extraction import extract_from_title

# %%
df = pd.read_csv("/Users/alessandromolinarroet/Desktop/ALL_JOB_DATA.csv")
df = df[:1500]

# %%
skill_path = "./lists/skills.txt"
field_path = "./lists/fields.txt"
model_name = "TechWolf/JobBERT-v2" # What is best model? Zero shot classification okay even if not really sentences?

extract_from_description(df, skill_path)
extract_from_title(df,field_path,treshold=0.3,model_name=model_name)
df.to_csv("jobs.csv", index=False)
# Out:
# Extracting skills : 100%|██████████| 1500/1500 [00:06<00:00, 221.79it/s]
# SKILLS EXTRACTED SUCCESFULLY
# Processing job titles: 100%|██████████| 1500/1500 [01:00<00:00, 24.75it/s]
# FIELDS AND LEVELS EXTRACTED SUCCESFULLY

# %%
pd.set_option("display.max_rows", None)
print(df["Field"].value_counts())
# Out:
# Field
# Software Engineering                  121
# Digital Marketing                      98
# Network Engineering                    84
# Account Management                     69
# Accounting                             55
# Talent Acquisition                     43
# Marketing                              40
# IT Support                             36
# Executive Leadership                   35
# Finance                                34
# Sales                                  32
# Physical Sciences                      31
# Brand Management                       30
# Agriculture & Farming                  29
# Manufacturing                          28
# Product Manager                        28
# Human Resources                        28
# Cloud Engineering                      27
# Artificial Intelligence                26
# Education                              26
# Consultant                             22
# Content Marketing                      21
# Construction                           21
# Executive Support                      21
# Web Development                        20
# Chemical Engineering                   19
# Food Service                           19
# Customer Support                       19
# Quality Control                        18
# Project Manager                        18
# Mechanical Repair                      18
# Public Relations                       18
# Administrative Support                 17
# Operations Management                  16
# Travel & Tourism                       16
# Public Safety                          15
# Life Sciences                          14
# Religious Services                     13
# Biomedical Engineer                    12
# Data & Analytics                       12
# Mechanical Engineering                 11
# Architecture                           11
# Industrial Engineering                 11
# Performing Arts                        11
# Business Development                   10
# Learning & Development                 10
# Audio & Video Production               10
# Aviation                                9
# Doctor                                  9
# Credit & Lending                        9
# Design                                  8
# Government & Public Administration      8
# Cybersecurity                           8
# Civil Engineering                       8
# UX                                      8
# Therapies                               7
# Skilled Trades                          7
# Electrical Engineering                  7
# Data engineering                        7
# Research Science                        6
# llied Health                            6
# Supply Chain                            6
# Advertising                             5
# Tax                                     5
# Insurance Services                      5
# Logistics                               5
# Fashion & Interior Design               4
# Mathematics & Statistics                4
# Dental                                  4
# Forestry & Conservation                 3
# Data Scientist                          3
# Animal Care & Veterinary                3
# Legal                                   3
# Market Research                         2
# Pharmacy                                2
# Other                                   2
# Sports & Recreation                     2
# Real Estate Sales                       2
# Risk & Compliance                       2
# Judiciary & Dispute Resolution          1
# Mental Health                           1
# Transportation                          1
# Compensation & Benefits                 1
# Hospitality                             1
# Office Management                       1
# Broadcast & Media                       1
# Nursing                                 1
# Name: count, dtype: int64

# %%
print(df[df["Field"]=="Digital Marketing"]["Job Title"])
# Out:
# 18                          Performance Marketing Manager
# 22                Senior Performance Marketing Manager:in
# 47              Performance Marketing Manager in Teilzeit
# 48                      CRM & Customer Journey Manager:in
# 56                               Remote Instagram Manager
# 63                                   Social Media Manager
# 82                               Online-Marketing-Manager
# 84                               Online-Marketing-Manager
# 86                        Werkstudent:in Digitalmarketing
# 87                                     E-Commerce Manager
# 88                      Senior Amazon Marketplace Manager
# 90                 Pflichtpraktikum Performance Marketing
# 110                       E-Commerce & Shopify Manager:in
# 112                     Digital Assets Operations Manager
# 121                      E-Commerce- / Onlineshop-Manager
# 127                              Online Marketing Manager
# 129             Pflichtpraktikum Online Marketing Manager
# 157                        Paid Social Campaign Concepter
# 159                       Paid Social Creative Strategist
# 209     E-Commerce Growth Operator:in für Shopify-D2C-...
# 214              Praktikum im Customer Success Management
# 219                                   PPC Performance Ads
# 222     Werkstudent:in Performance Marketing & Automation
# 243          Team Lead Performance & Influencer Marketing
# 253                  Innendienstmitarbeiter B2B Marketing
# 286                                    E-Commerce Manager
# 292                                           SEO Manager
# 294     Jahrespraktikum 2026 im Bereich Social Media u...
# 307                                   Vertriebsleiter B2C
# 313                      Praktikant:in Growth & Marketing
# 331             Praktikum Online Marketing & Media Design
# 332                Consultant Digital Workplace Solutions
# 348               Digital Operations Specialist in Berlin
# 359                              B2B Marketing Spezialist
# 367              Customer Success Manager Schwerpunkt SEO
# 374                                  Social Media Manager
# 388                        Senior Social Media Manager:in
# 414                             Digital Marketing Manager
# 420                        Senior Social Media Manager:in
# 436                      E-Commerce Content & SEO Manager
# 474                          Marketing Automation Manager
# 479                        Paid Social Campaign Concepter
# 494                       Paid Social Creative Strategist
# 499                     Online Marketing- & Event-Manager
# 507                         SAP Spezialist:in EAM/PM & QM
# 511                         Praktikum im Online Marketing
# 527                               Social Media Manager/in
# 528        Online-Redakteur:in mit SEO Erfahrung für DACH
# 542                      Senior Digital Marketing Manager
# 543                  Senior Performance Marketing Manager
# 549                       Remote Social Media Ads Manager
# 550                              Online Marketing Manager
# 554                       Google Manager*in im Homeoffice
# 583              SEO / SEA & Performance Marketing Expert
# 585              Google Ads Performance Marketing Manager
# 588                     Social Media Marketing Manager:in
# 589                                        CRM Manager:in
# 594            Customer Engagement & Monetization Manager
# 685       Online Marketing Manager in Teil- oder Vollzeit
# 688                              Online Marketing Manager
# 692                                  Social Media Manager
# 703                           Affiliate Marketing Manager
# 708                  Performance Marketing Manager Amazon
# 709                                Viral Marketing Intern
# 711                                           CRM Manager
# 729     Online-Redakteur:in mit Social Media Erfahrung...
# 755                         Performance Marketing Manager
# 815                E-Commerce Manager/in mit Fokus Amazon
# 816                E-Commerce Manager/in mit Fokus Amazon
# 828             Pflichtpraktikum Online Marketing Manager
# 830                              Online Marketing Manager
# 851                         Performance Marketing Manager
# 854                          Influencer Marketing Minijob
# 870          Datenbankmanager*in CRM & Online Fundraising
# 881                    Performance Advertising Specialist
# 912                              Online Marketing Manager
# 913                       Remote Social Media Ads Manager
# 920                              Junior Expansion Manager
# 921                  Senior Performance Marketing Manager
# 925      Performance Marketing & Online Marketing Manager
# 927                               Digitalisierungsmanager
# 933     Digital Implementation & Partner Success Speci...
# 934                SEO-Sachbearbeiter Offpage & Redaktion
# 940                                  Paid Social Marketer
# 956                Ebay Gebrauchtmotorrad Teile Verkäufer
# 961            Unterstützung im Bereich Digital Marketing
# 965                        Werkstudentin Online Marketing
# 991                         Performance Marketing Manager
# 1000                        Performance Marketing Manager
# 1149                                   Community & Growth
# 1173       Praktikum B2B-Marketing im E-Commerce Start-Up
# 1176                            Digital Marketing Manager
# 1177                              SEO Performance Manager
# 1180                                 Social Media Manager
# 1194                              Social Media Strategist
# 1271    PCMM Technician (Test Technician III) with Sec...
# 1382    Digital Strategy & Brand Engagement Manager – ...
# 1399                                      Ecommerce Buyer
# Name: Job Title, dtype: object

# %%
print(df[df["Field"]=="Cloud Engineering"]["Skills"])
# Out:
# 13      [Aws, Docs, Kafka, Kubernetes, Linux, Office, ...
# 41      [C, Linux, Meet, Powershell, Rust, Windows, Wi...
# 75      [Android, Bitbucket, Gitlab, Graphql, Ios, Jav...
# 118     [Access, Azure Devops, Github, Go, Graphql, Ja...
# 163                                                    []
# 316                                                    []
# 372     [Cloud Platform, Github, Google, Meet, Python,...
# 433               [Ansible, Kubernetes, Teams, Terraform]
# 441          [Docker, Junit, Kubernetes, Postman, Python]
# 465     [Ansible, Bash, Kubernetes, Linux, Teams, Terr...
# 484                                               [Teams]
# 592     [Active Directory, Aws, Google, Linux, Office,...
# 651     [Linux, Postgresql, Unix, Windows, Windows Ser...
# 653                [Linux, Unix, Windows, Windows Server]
# 654     [Linux, Postgresql, Unix, Windows, Windows Ser...
# 660     [Linux, Postgresql, Unix, Windows, Windows Ser...
# 676           [Docker, Gitlab, Junit, Kubernetes, Python]
# 720     [Docker, Github, Kubernetes, Linux, Office, Po...
# 764     [Ansible, Chef, Confluence, Github, Gitlab, Ji...
# 812     [Ansible, Azure Devops, Bitbucket, Css, Docker...
# 942                        [Office, Power Bi, Sql, Teams]
# 1024    [Analytics, Github, Gitlab, Kubernetes, Linux,...
# 1032                                           [R, Teams]
# 1114    [Ansible, Aws, Bash, Confluence, Gitlab, Go, J...
# 1131                                   [Access, C, Teams]
# 1150    [Ansible, Bash, Go, Linux, Python, Teams, Terr...
# 1152    [Confluence, Figma, Github, Jira, Office, Powe...
# Name: Skills, dtype: object
